# %%
#Se usa fuerza bruta
#Para cada ruta generada, se calcula la distancia total recorrida sumando las distancias entre cada par de ciudades consecutivas en la ruta.
#Se compara la distancia de cada ruta con la distancia mínima encontrada hasta el momento. Si se encuentra una ruta con una distancia menor, se actualiza la distancia mínima y se guarda la ruta correspondiente como la mejor ruta.
# Este método garantiza encontrar la solución óptima, ya que evalúa todas las posibilidades.
#El tiempo de ejecución crece exponencialmente con el número de ciudades, haciéndolo inviable para problemas con muchas ciudades.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import itertools
from geopy.distance import geodesic  # Para calcular distancias geodésicas

# %%
ciudades = {
        'Quito': (-0.1807, -78.4678),
        'Guayaquil': (-2.1709, -79.9226),
        'Cuenca': (-2.8964, -79.0042),
        'Ambato': (-1.2443, -78.6139),
        'Machala': (-3.2578, -79.9639),
        'Manta': (-0.9675, -80.7356),
        'Portoviejo': (-1.0546, -80.4528),
        'Loja': (-4.0046, -79.2127),
        'Riobamba': (-1.6742, -78.6486),
        'Esmeraldas': (0.9672, -79.6509)
    }

# %%
distancias = [[0] * len(ciudades) for _ in range(len(ciudades))]
for i, (ciudad1, coords1) in enumerate(ciudades.items()): # Fixed: Removed extra indentation
    for j, (ciudad2, coords2) in enumerate(ciudades.items()):
        if i != j:
            distancias[i][j] = geodesic(coords1, coords2).km

# %%
lista_ciudades = list(ciudades.keys())
G = nx.Graph()
# The following lines had unexpected indentation
# Fixed: Removed extra indentation
for i in range(len(lista_ciudades)):
    for j in range(i + 1, len(lista_ciudades)):
        G.add_edge(lista_ciudades[i], lista_ciudades[j], weight=distancias[i][j])

# %%
rutas_posibles = itertools.permutations(range(1, len(lista_ciudades)))
mejor_distancia = float('inf') # Fixed: Removed extra indentation
mejor_ruta = [] # Fixed: Removed extra indentation
# ... (resto del código similar, usando lista_ciudades en lugar de ciudades)

# %%
for ruta in rutas_posibles:
    distancia_actual = 0
    ruta_actual = [0] + list(ruta) + [0]  # Agregar Quito al inicio y al final

    for i in range(len(ruta_actual) - 1):
        ciudad1_index = ruta_actual[i]
        ciudad2_index = ruta_actual[i + 1]
        distancia_actual += distancias[ciudad1_index][ciudad2_index]

    if distancia_actual < mejor_distancia:
        mejor_distancia = distancia_actual
        mejor_ruta = ruta_actual

# %%
print("Mejor ruta:")
for i in range(len(mejor_ruta)):
    print(lista_ciudades[mejor_ruta[i]], end=" -> " if i < len(mejor_ruta) - 1 else "\n")
print(f"Distancia total: {mejor_distancia}")
# Out:
# Mejor ruta:
# Quito -> Ambato -> Riobamba -> Cuenca -> Loja -> Machala -> Guayaquil -> Portoviejo -> Manta -> Esmeraldas -> Quito
# Distancia total: 1267.9117450227573

# %%
import folium

# %%
# Crea un mapa centrado en Quito
mapa = folium.Map(location=ciudades['Quito'], zoom_start=7)

# %%
# Agrega marcadores para cada ciudad en la mejor ruta
for ciudad_index in mejor_ruta:
    nombre_ciudad = lista_ciudades[ciudad_index]
    coordenadas = ciudades[nombre_ciudad]
    folium.Marker(location=coordenadas, popup=nombre_ciudad).add_to(mapa)

# %%
# Crea una lista de coordenadas para la línea de la ruta
ruta_coordenadas = [ciudades[lista_ciudades[i]] for i in mejor_ruta]

# Agrega la línea de la ruta al mapa
folium.PolyLine(ruta_coordenadas, color="blue", weight=2.5, opacity=1).add_to(mapa)

# %%
# Muestra el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4540cf8a4b217b27cb4787d4644778b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4540cf8a4b217b27cb4787d4644778b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4540cf8a4b217b27cb4787d4644778b9 = L.map(
#                 &quot;map_4540cf8a4b217b27cb4787d4644778b9&quot;,
#                 {
#                     center: [-0.1807, -78.4678],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cf0ca895990a3f6c85fe7bddd854c62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cf0ca895990a3f6c85fe7bddd854c62.addTo(map_4540cf8a4b217b27cb4787d4644778b9);
#
#
#             var marker_7c850926ecf57b67c6e4362ba2508c43 = L.marker(
#                 [-0.1807, -78.4678],
#                 {
# }
#             ).addTo(map_4540cf8a4b217b27cb4787d4644778b9);
#
#
#         var popup_87aa7f24ab1237aa1f38b0d2b07b3edf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78c0f8bb9ffe59b424019d5ad744f6b6 = $(`&lt;div id=&quot;html_78c0f8bb9ffe59b424019d5ad744f6b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_87aa7f24ab1237aa1f38b0d2b07b3edf.setContent(html_78c0f8bb9ffe59b424019d5ad744f6b6);
#
#
#
#         marker_7c850926ecf57b67c6e4362ba2508c43.bindPopup(popup_87aa7f24ab1237aa1f38b0d2b07b3edf)
#         ;
#
#
#
#
#             var marker_4be1abbec24356ce710bec15dcdaa42b = L.marker(
#                 [-1.2443, -78.6139],
#                 {
# }
#             ).addTo(map_4540cf8a4b217b27cb4787d4644778b9);
#
#
#         var popup_a2e6320271af6ae1bd36d0eb9c52c026 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66319e248abdd3727acf558d183faec9 = $(`&lt;div id=&quot;html_66319e248abdd3727acf558d183faec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ambato&lt;/div&gt;`)[0];
#                 popup_a2e6320271af6ae1bd36d0eb9c52c026.setContent(html_66319e248abdd3727acf558d183faec9);
#
#
#
#         marker_4be1abbec24356ce710bec15dcdaa42b.bindPopup(popup_a2e6320271af6ae1bd36d0eb9c52c026)
#         ;
#
#
#
#
#             var marker_8542761a5bb7fb0b164336a96a150422 = L.marker(
#                 [-1.6742, -78.6486],
#                 {
# }
#             ).addTo(map_4540cf8a4b217b27cb4787d4644778b9);
#
#
#         var popup_35a7a75d30046496cea92f71cfc50834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e66ffdfb34521ad27642a20ff38f484 = $(`&lt;div id=&quot;html_7e66ffdfb34521ad27642a20ff38f484&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Riobamba&lt;/div&gt;`)[0];
#                 popup_35a7a75d30046496cea92f71cfc50834.setContent(html_7e66ffdfb34521ad27642a20ff38f484);
#
#
#
#         marker_8542761a5bb7fb0b164336a96a150422.bindPopup(popup_35a7a75d30046496cea92f71cfc50834)
#         ;
#
#
#
#
#             var marker_47ced69aba72be76b2ef6260510be5bb = L.marker(
#                 [-2.8964, -79.0042],
#                 {
# }
#             ).addTo(map_4540cf8a4b217b27cb4787d4644778b9);
#
#
#         var popup_a97da03b8bc936ca84c002695b415087 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e67bf6222b093ee344e71f693e067ca4 = $(`&lt;div id=&quot;html_e67bf6222b093ee344e71f693e067ca4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cuenca&lt;/div&gt;`)[0];
#                 popup_a97da03b8bc936ca84c002695b415087.setContent(html_e67bf6222b093ee344e71f693e067ca4);
#
#
#
#         marker_47ced69aba72be76b2ef6260510be5bb.bindPopup(popup_a97da03b8bc936ca84c002695b415087)
#         ;
#
#
#
#
#             var marker_4f148448bed37f6c34f2d870bb4e3aa9 = L.marker(
#                 [-4.0046, -79.2127],
#                 {
# }
#             ).addTo(map_4540cf8a4b217b27cb4787d4644778b9);
#
#
#         var popup_5e2340670d98b821f603f7700d7963e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f889b717d3b0e83c0d25a825ee46405 = $(`&lt;div id=&quot;html_8f889b717d3b0e83c0d25a825ee46405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Loja&lt;/div&gt;`)[0];
#                 popup_5e2340670d98b821f603f7700d7963e9.setContent(html_8f889b717d3b0e83c0d25a825ee46405);
#
#
#
#         marker_4f148448bed37f6c34f2d870bb4e3aa9.bindPopup(popup_5e2340670d98b821f603f7700d7963e9)
#         ;
#
#
#
#
#             var marker_b64f57d74001fa0831babf0d3cd91fa2 = L.marker(
#                 [-3.2578, -79.9639],
#                 {
# }
#             ).addTo(map_4540cf8a4b217b27cb4787d464477
